# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
import os
os.chdir("/content/drive/MyDrive/CMPT733_Final_Project")
# !ls

# %%
files = [file for file in os.listdir("covid_tweet") if "media_" in file]
files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8bbe27268900> in <module>()
# ----> 1 files = [file for file in os.listdir("covid_tweet") if "media_" in file]
#       2 files
#
# NameError: name 'os' is not defined
